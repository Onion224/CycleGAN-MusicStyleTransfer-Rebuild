# %%
import pypianoroll
multitrack = pypianoroll.read("./datasets/train/Classical/ABC - Frank Zappa.mid")
pypianoroll.plot(multitrack)
# Out:
# [<AxesSubplot:xlabel='time (beat)', ylabel='\n\npitch'>,
#  <AxesSubplot:xlabel='time (beat)', ylabel='\n\npitch'>,
#  <AxesSubplot:xlabel='time (beat)', ylabel='\n\npitch'>,
#  <AxesSubplot:xlabel='time (beat)', ylabel='\n\npitch'>]
